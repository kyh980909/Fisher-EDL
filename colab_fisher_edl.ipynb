# %% [markdown]
# # Fisher-EDL Colab Runner
# Run CIFAR-10 training with SVHN/CIFAR-100 OOD evaluation.

# %%
# Clone repo (replace with your repo URL if needed)
# !git clone https://github.com/kyh980909/Fisher-EDL.git
# %cd Fisher-EDL
# Out:
# fatal: destination path 'Fisher-EDL' already exists and is not an empty directory.
# /content/Fisher-EDL

# %%
# Install dependencies
# !pip -q install torch torchvision wandb

# %%
# Optional: login to W&B
import wandb
wandb.login()
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: yhkim to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# Train Fisher-EDL with ResNet18
# !python run_cifar_experiment.py --method fisher --backbone resnet18 --epochs 100 --batch-size 128 --beta 1.0 --gamma 1.0
# Out:
# 100% 170M/170M [00:01<00:00, 96.7MB/s]
# 100% 64.3M/64.3M [00:05<00:00, 12.2MB/s]
# 100% 169M/169M [00:01<00:00, 88.9MB/s]
# Running fisher on cpu. logs -> runs/cifar_fisher_20260106_074406

# %%
# Evaluate a saved checkpoint (edit path accordingly)
# !python run_cifar_eval.py --ckpt runs/cifar_fisher_YYYYMMDD_HHMMSS/best_val_acc.pt
